# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
#print(os.listdir())

import warnings
warnings.filterwarnings('ignore')

plt.style.use('bmh')

# %%
#upload dataset

# %%
import pandas as pd

#read_file = pd.read_excel (r'C:\Users\Gawa\Desktop\dataset.xlsx')
read_file.to_csv (r'dataset.csv', index = None, header=True)

# %%
#read dataset

# %%
df= pd.read_csv("dataset.csv")

# %%
#workwith missing data

# %%
# filling missing values with medians of the columns
df = df.fillna(df.median())

# %%
df.isnull().any()
# Out:
# Street                      False
# substreet                   False
# Square                      False
# Floor                       False
# rooms                       False
# bathrooms                   False
# house kind                  False
# organizational character    False
# garden                      False
# garden square               False
# tree or water               False
# swimming pool               False
# general condition           False
# floor material              False
# kitchen status              False
# build year                  False
# lift                        False
# num. of floors              False
# Price                       False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3981 entries, 0 to 3980
# Data columns (total 19 columns):
# Street                      3981 non-null int64
# substreet                   3981 non-null int64
# Square                      3981 non-null int64
# Floor                       3981 non-null int64
# rooms                       3981 non-null int64
# bathrooms                   3981 non-null int64
# house kind                  3981 non-null int64
# organizational character    3981 non-null int64
# garden                      3981 non-null float64
# garden square               3981 non-null int64
# tree or water               3981 non-null float64
# swimming pool               3981 non-null float64
# general condition           3981 non-null int64
# floor material              3981 non-null int64
# kitchen status              3981 non-null int64
# build year                  3981 non-null int64
# lift                        3981 non-null float64
# ...

# %%
df.head()
# Out:
#    Street  substreet  Square  Floor  rooms  bathrooms  house kind  \
# 0       1          0     175     -1      5          1           0
# 1       1          0     175      0      5          2           1
# 2       1          1     130      0      4          2           1
# 3       1          1     130     -1      4          2           0
# 4       1          1     170      0      5          1           1
#
#    organizational character  garden  garden square  tree or water  \
# 0                        12     1.0             50            1.0
# 1                        12     0.0              0            0.0
# 2                        32     0.0              0            0.0
# 3                        32     1.0            100            1.0
# 4                        32     0.0              0            0.0
#
#    swimming pool  general condition  floor material  kitchen status  \
# 0            0.0                  3               2               1
# ...

# %%
#data visualization

# %%
sns.barplot(df["Street"],df["Price"])

# %%
sns.barplot(df["substreet"],df["Price"])

# %%
sns.barplot(df["kitchen status"],df["Price"])

# %%
sns.barplot(df["garden square"],df["Price"])

# %%
sns.barplot(df["tree or water"],df["Price"])

# %%
sns.barplot(df["general condition"],df["Price"])

# %%
sns.barplot(df["house kind"],df["Price"])

# %%
sns.barplot(df["organizational character"],df["Price"])

# %%
sns.barplot(df["floor material"],df["Price"])

# %%
sns.barplot(df["Street"],df["Price"])

# %%
sns.barplot(df["Floor"],df["Price"])

# %%
sns.barplot(df["substreet"],df["Price"])

# %%
sns.barplot(df["Square"],df["Price"])

# %%
sns.barplot(df["rooms"],df["Price"])

# %%
sns.barplot(df["bathrooms"],df["Price"])

# %%
sns.barplot(df["build year"],df["Price"])

# %%
sns.barplot(df["num. of floors"],df["Price"])

# %%
sns.barplot(df["swimming pool"],df["Price"])

# %%
#correlation Analysis

# %%
df.corr()
# Out:
#                             Street  substreet    Square     Floor     rooms  \
# Street                    1.000000   0.091085 -0.124795  0.057879 -0.076226
# substreet                 0.091085   1.000000 -0.216341 -0.017499 -0.137748
# Square                   -0.124795  -0.216341  1.000000 -0.040449  0.807586
# Floor                     0.057879  -0.017499 -0.040449  1.000000 -0.013991
# rooms                    -0.076226  -0.137748  0.807586 -0.013991  1.000000
# bathrooms                -0.013840  -0.036182  0.439783 -0.020410  0.351401
# house kind                0.107803   0.021568 -0.192579  0.770891 -0.146137
# organizational character -0.278972  -0.422867  0.043906 -0.023264  0.017972
# garden                   -0.133020  -0.123767  0.206554 -0.446291  0.180191
# garden square            -0.160803  -0.091149  0.183810 -0.298043  0.205380
# tree or water            -0.170555  -0.113251  0.225749 -0.303313  0.251120
# ...

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Street  substreet  Square  Floor  rooms  bathrooms  house kind  \
# 0       1          0     175     -1      5          1           0
# 1       1          0     175      0      5          2           1
# 2       1          1     130      0      4          2           1
# 3       1          1     130     -1      4          2           0
# 4       1          1     170      0      5          1           1
#
#    organizational character  garden  garden square  tree or water  \
# 0                        12     1.0             50            1.0
# 1                        12     0.0              0            0.0
# 2                        32     0.0              0            0.0
# 3                        32     1.0            100            1.0
# 4                        32     0.0              0            0.0
#
#    swimming pool  general condition  floor material  kitchen status  \
# 0            0.0                  3               2               1
# ...

# %%
for i in range(0, len(df_num.columns), 5):
    sns.pairplot(data=df_num,
                x_vars=df_num.columns[i:i+5],
                y_vars=['Price'])

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Street'])
plt.subplot(1,2,2)
sns.distplot(df['Price'])
plt.show()
plt.subplot(1,2,2)
sns.distplot(df['general condition'])
plt.show()
plt.subplot(1,2,2)
sns.distplot(df['Square'])
plt.show()
plt.subplot(1,2,2)
sns.distplot(df['kitchen status'])
plt.show()
plt.subplot(1,2,2)
sns.distplot(df['Floor'])
plt.show()
plt.subplot(1,2,2)
sns.distplot(df['rooms'])
plt.show()

# %%
corr = df_num.drop('Price', axis=1).corr() # We already examined SalePrice correlations
plt.figure(figsize=(10, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.corr(), annot=True, linewidths=3.0)

# %%
print(df.corr()["Price"].abs().sort_values(ascending=False))
# Out:
# Price                       1.000000
# kitchen status              0.563915
# floor material              0.556570
# general condition           0.482336
# tree or water               0.472197
# Square                      0.429709
# rooms                       0.424553
# swimming pool               0.398255
# garden square               0.364237
# garden                      0.358313
# num. of floors              0.246529
# bathrooms                   0.236017
# organizational character    0.147195
# house kind                  0.120050
# Floor                       0.073797
# substreet                   0.043573
# Street                      0.012079
# lift                        0.010709
# build year                  0.004264
# Name: Price, dtype: float64

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.distplot(df['Price'], ax=axes[0])
sns.scatterplot(x='Price',y='Square', data=df, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions [USD]', ylabel='', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Square', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

# %%
df.plot(x='Price', y='Floor', style='o')
plt.title('MinTemp vs MaxTemp')
plt.xlabel('Price')
plt.ylabel('rooms')
plt.show()

# %%
#split dataset

# %%
from sklearn.model_selection import train_test_split

predictors = df.drop("Price",axis=1)
target = df["Price"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.30,random_state=0)

# %%
#X_train,X_val,Y_train,Y_val = train_test_split(X_train,Y_train,test_size=0.20,random_state=0)

# %%
#train models

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=5)

model = GridSearchCV(knn, params, cv=5)
model.fit(X_train,Y_train)
model.best_params_
# Out:
# {'n_neighbors': 6}

# %%
#regression::::::::::::::::::::

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf = DecisionTreeRegressor(random_state=42)

sk_folds = StratifiedKFold(n_splits = 5)
clf.fit( X_train, Y_train)
dtr_scores = cross_val_score(clf, X_train, Y_train, cv = 5)

print("Cross Validation Scores: ", dtr_scores)
print("Average CV Score: ", dtr_scores.mean())
print("Number of CV Scores used in Average: ", len(dtr_scores))
# Out:
# Cross Validation Scores:  [0.80664921 0.80650689 0.77325119 0.70886254 0.85089095]
# Average CV Score:  0.7892321555332993
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
dtr_score = r2_score(Y_test, Y_pred)
dtr_score
# Out:
# 0.8381215448501121

# %%
Y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
dtr_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', dtr_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 24.116929860664907
# Root mean square error 581.6263059042307

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   34.000000
# 1367   115.0  114.000000
# 224    150.0  150.000000
# 641     85.0   95.000000
# 1290   115.0  110.000000
# 840     80.0   90.000000
# 326    150.0  140.000000
# 1895   135.0  150.000000
# 775    100.0   70.000000
# 3704    47.0   60.000000
# 1530    40.0   56.000000
# 1739   155.0  158.000000
# 3642    30.0   33.000000
# 1300   120.0  130.000000
# 2643   105.0  100.000000
# 979     31.0   36.000000
# 3039    67.0   63.000000
# 1385    27.0   30.000000
# 1377    71.0   72.500000
# 3392    65.0   60.000000
# 248    120.0   90.000000
# 572    115.0  100.000000
# 3800   100.0   82.000000
# 661    100.0  200.000000
# 1287    90.0  105.000000
# 1327    94.0  105.000000
# 962     17.0   22.500000
# 2604    95.0  100.000000
# 31     160.0  200.000000
# 3934    37.0   27.000000
# ...      ...         ...
# 1014    14.0   16.000000
# 3063    37.0   37.000000
# 1267    40.0   45.000000
# 3282    33.0   35.000000
# 3009    42.0   40.000000
# ...

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf = LinearRegression()

sk_folds = StratifiedKFold(n_splits = 5)
clf.fit( X_train, Y_train)
lr_scores = cross_val_score(clf, X_train,Y_train, cv = 5)

print("Cross Validation Scores: ", lr_scores)
print("Average CV Score: ", lr_scores.mean())
print("Number of CV Scores used in Average: ", len(lr_scores))
# Out:
# Cross Validation Scores:  [0.76603831 0.76873371 0.73707302 0.65538597 0.70101671]
# Average CV Score:  0.7256495426056765
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
lr_score = r2_score(Y_test, Y_pred)
lr_score
# Out:
# 0.7361698770518049

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
lr_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', lr_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 30.788581800982683
# Root mean square error 947.936769315802

# %%
Y_pred = clf.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   19.905865
# 1367   115.0  109.235258
# 224    150.0  128.610196
# 641     85.0   71.247000
# 1290   115.0  129.961359
# 840     80.0   86.914352
# 326    150.0  121.441742
# 1895   135.0  130.963263
# 775    100.0   69.758705
# 3704    47.0   52.346105
# 1530    40.0   48.813243
# 1739   155.0  137.676962
# 3642    30.0   43.863236
# 1300   120.0  117.715275
# 2643   105.0  102.861573
# 979     31.0   29.531363
# 3039    67.0   76.370414
# 1385    27.0   31.595448
# 1377    71.0   61.731678
# 3392    65.0  105.506633
# 248    120.0   64.549368
# 572    115.0   98.580566
# 3800   100.0   75.338064
# 661    100.0  109.231273
# 1287    90.0  135.332607
# 1327    94.0  121.176252
# 962     17.0   18.270838
# 2604    95.0   96.720015
# 31     160.0  225.200321
# 3934    37.0   38.495244
# ...      ...         ...
# 1014    14.0   15.435399
# 3063    37.0   45.258353
# 1267    40.0   86.363537
# 3282    33.0   56.528151
# 3009    42.0   47.525921
# ...

# %%
from sklearn.linear_model import Ridge
from sklearn import datasets
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf = Ridge(alpha=0)

sk_folds = StratifiedKFold(n_splits = 2)
clf.fit(X_train, Y_train)
r_scores = cross_val_score(clf, X_train, Y_train, cv = 5)

print("Cross Validation Scores: ", r_scores)
print("Average CV Score: ", r_scores.mean())
print("Number of CV Scores used in Average: ", len(r_scores))
# Out:
# Cross Validation Scores:  [0.76603831 0.76873371 0.73707302 0.65538597 0.70101671]
# Average CV Score:  0.7256495426056805
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
r_score = r2_score(Y_test, Y_pred)
r_score
# Out:
# 0.7361698770518046

# %%
Y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
r_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', r_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 30.788581800982698
# Root mean square error 947.9367693158031

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   19.905865
# 1367   115.0  109.235258
# 224    150.0  128.610196
# 641     85.0   71.247000
# 1290   115.0  129.961359
# 840     80.0   86.914352
# 326    150.0  121.441742
# 1895   135.0  130.963263
# 775    100.0   69.758705
# 3704    47.0   52.346105
# 1530    40.0   48.813243
# 1739   155.0  137.676962
# 3642    30.0   43.863236
# 1300   120.0  117.715275
# 2643   105.0  102.861573
# 979     31.0   29.531363
# 3039    67.0   76.370414
# 1385    27.0   31.595448
# 1377    71.0   61.731678
# 3392    65.0  105.506633
# 248    120.0   64.549368
# 572    115.0   98.580566
# 3800   100.0   75.338064
# 661    100.0  109.231273
# 1287    90.0  135.332607
# 1327    94.0  121.176252
# 962     17.0   18.270838
# 2604    95.0   96.720015
# 31     160.0  225.200321
# 3934    37.0   38.495244
# ...      ...         ...
# 1014    14.0   15.435399
# 3063    37.0   45.258353
# 1267    40.0   86.363537
# 3282    33.0   56.528151
# 3009    42.0   47.525921
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf = Lasso(alpha=1.0)

sk_folds = StratifiedKFold(n_splits = 2)
clf.fit( X_train, Y_train)
l_scores = cross_val_score(clf, X_train,Y_train, cv = 5)

print("Cross Validation Scores: ", l_scores)
print("Average CV Score: ", l_scores.mean())
print("Number of CV Scores used in Average: ", len(l_scores))
# Out:
# Cross Validation Scores:  [0.76313459 0.73932896 0.73375987 0.62497247 0.65925609]
# Average CV Score:  0.704090394481684
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
l_score = r2_score(Y_test, Y_pred)
l_score
# Out:
# 0.7200112110107217

# %%
Y_pred = clf.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   28.818411
# 1367   115.0  105.798752
# 224    150.0  126.657989
# 641     85.0   75.025481
# 1290   115.0  116.140090
# 840     80.0   83.744446
# 326    150.0  130.190220
# 1895   135.0  127.230062
# 775    100.0   74.945227
# 3704    47.0   53.421668
# 1530    40.0   50.428324
# 1739   155.0  133.224702
# 3642    30.0   34.836989
# 1300   120.0  117.423272
# 2643   105.0  107.699268
# 979     31.0   35.190066
# 3039    67.0   76.643139
# 1385    27.0   32.453725
# 1377    71.0   67.189356
# 3392    65.0  110.738540
# 248    120.0   75.636892
# 572    115.0  100.392710
# 3800   100.0   66.570436
# 661    100.0  109.618782
# 1287    90.0  120.428465
# 1327    94.0  121.923422
# 962     17.0   21.913952
# 2604    95.0   97.970672
# 31     160.0  289.483521
# 3934    37.0   39.376944
# ...      ...         ...
# 1014    14.0   18.479002
# 3063    37.0   47.368286
# 1267    40.0   92.537031
# 3282    33.0   60.655362
# 3009    42.0   49.962006
# ...

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
l_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', l_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 31.717417274965275
# Root mean square error 1005.9945585942655

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   28.818411
# 1367   115.0  105.798752
# 224    150.0  126.657989
# 641     85.0   75.025481
# 1290   115.0  116.140090
# 840     80.0   83.744446
# 326    150.0  130.190220
# 1895   135.0  127.230062
# 775    100.0   74.945227
# 3704    47.0   53.421668
# 1530    40.0   50.428324
# 1739   155.0  133.224702
# 3642    30.0   34.836989
# 1300   120.0  117.423272
# 2643   105.0  107.699268
# 979     31.0   35.190066
# 3039    67.0   76.643139
# 1385    27.0   32.453725
# 1377    71.0   67.189356
# 3392    65.0  110.738540
# 248    120.0   75.636892
# 572    115.0  100.392710
# 3800   100.0   66.570436
# 661    100.0  109.618782
# 1287    90.0  120.428465
# 1327    94.0  121.923422
# 962     17.0   21.913952
# 2604    95.0   97.970672
# 31     160.0  289.483521
# 3934    37.0   39.376944
# ...      ...         ...
# 1014    14.0   18.479002
# 3063    37.0   47.368286
# 1267    40.0   92.537031
# 3282    33.0   60.655362
# 3009    42.0   49.962006
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf = RandomForestRegressor()

sk_folds = StratifiedKFold(n_splits = 2)
clf.fit(X_train, Y_train)
rfr_scores = cross_val_score(clf, X_train, Y_train, cv = 5)

print("Cross Validation Scores: ", rfr_scores)
print("Average CV Score: ", rfr_scores.mean())
print("Number of CV Scores used in Average: ", len(rfr_scores))
# Out:
# Cross Validation Scores:  [0.89249429 0.90891306 0.86310374 0.88531898 0.88143916]
# Average CV Score:  0.8862538454898778
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
rfr_score = r2_score(Y_test, Y_pred)
rfr_score
# Out:
# 0.8821764891311741

# %%
Y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
rfr_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', rfr_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 20.575172005186158
# Root mean square error 423.33770304299617

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred,'df':Y_test-Y_pred})
df
# Out:
#       Actual   Predicted          df
# 3322    21.0   35.900000  -14.900000
# 1367   115.0  100.000000   15.000000
# 224    150.0  146.500000    3.500000
# 641     85.0   97.000000  -12.000000
# 1290   115.0  115.300000   -0.300000
# 840     80.0   96.666667  -16.666667
# 326    150.0  132.500000   17.500000
# 1895   135.0  149.600000  -14.600000
# 775    100.0   95.500000    4.500000
# 3704    47.0   48.500000   -1.500000
# 1530    40.0   49.600000   -9.600000
# 1739   155.0  163.600000   -8.600000
# 3642    30.0   32.600000   -2.600000
# 1300   120.0  127.900000   -7.900000
# 2643   105.0  101.000000    4.000000
# 979     31.0   35.533333   -4.533333
# 3039    67.0   60.350000    6.650000
# 1385    27.0   30.300000   -3.300000
# 1377    71.0   78.083333   -7.083333
# 3392    65.0   76.600000  -11.600000
# 248    120.0  112.500000    7.500000
# 572    115.0  102.500000   12.500000
# 3800   100.0  100.100000   -0.100000
# 661    100.0  126.500000  -26.500000
# ...

# %%
y_pred = model.predict(X_test)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(Y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(Y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(Y_test,y_pred))
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(Y_test,y_pred)
# Perfect predictions
plt.plot(Y_test,Y_test,'r')
# Out:
# MAE: 16.371115760111575
# MSE: 1074.5687635983265
# RMSE: 32.780615668384364
# VarScore: 0.7010445892359514

# %%
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf =SVR()

sk_folds = StratifiedKFold(n_splits = 2)
clf.fit( X_train,Y_train)
svr_scores = cross_val_score(clf, X_train,Y_train, cv = 5)

print("Cross Validation Scores: ", svr_scores)
print("Average CV Score: ", svr_scores.mean())
print("Number of CV Scores used in Average: ", len(svr_scores))
# Out:
# Cross Validation Scores:  [0.05682815 0.0404174  0.06046571 0.087304   0.02540904]
# Average CV Score:  0.05408485949269996
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
svr_score = r2_score(Y_test, Y_pred)
svr_score
# Out:
# 0.10966441575863506

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_squared_error,explained_variance_score, r2_score


clf =KNeighborsRegressor(n_neighbors=5)

sk_folds = StratifiedKFold(n_splits = 2)
clf.fit( X_train, Y_train)
knr_scores = cross_val_score(clf, X_train, Y_train, cv = 5)

print("Cross Validation Scores: ", knr_scores)
print("Average CV Score: ", knr_scores.mean())
print("Number of CV Scores used in Average: ", len(knr_scores))
# Out:
# Cross Validation Scores:  [0.69110365 0.76811219 0.66502408 0.65905603 0.64757533]
# Average CV Score:  0.6861742571942708
# Number of CV Scores used in Average:  5

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
knr_score = r2_score(Y_test, Y_pred)
knr_score
# Out:
# 0.7111381633714957

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
knr_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', knr_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 32.216071381068886
# Root mean square error 1037.8752552301255

# %%
np.mean(np.absolute(Y_pred-Y_test))
# Out:
# 15.77916317991632

# %%
print('Variance score: %.2f' % clf.score(X_test, Y_test))
# Out:
# Variance score: 0.71

# %%
Y_pred = clf.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual  Predicted
# 3322    21.0       29.2
# 1367   115.0       96.2
# 224    150.0      156.0
# 641     85.0       62.0
# 1290   115.0      110.0
# 840     80.0       78.4
# 326    150.0      139.0
# 1895   135.0      129.8
# 775    100.0      106.0
# 3704    47.0       49.0
# 1530    40.0       55.4
# 1739   155.0      151.2
# 3642    30.0       31.6
# 1300   120.0       99.0
# 2643   105.0       99.0
# 979     31.0       36.8
# 3039    67.0       55.2
# 1385    27.0       34.2
# 1377    71.0      130.0
# 3392    65.0       81.0
# 248    120.0       82.0
# 572    115.0      110.0
# 3800   100.0       92.0
# 661    100.0       94.2
# 1287    90.0       98.0
# 1327    94.0      105.8
# 962     17.0       22.0
# 2604    95.0       94.0
# 31     160.0      107.0
# 3934    37.0       31.2
# ...      ...        ...
# 1014    14.0       19.0
# 3063    37.0       38.8
# 1267    40.0       64.8
# 3282    33.0       47.8
# 3009    42.0       41.6
# 1341   115.0      120.0
# ...

# %%
# evaluate adaboost ensemble for regression
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import AdaBoostRegressor
# define the model
model = AdaBoostRegressor()
# evaluate the model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
adabr_scores = cross_val_score(model, X_train,Y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('MAE: %.3f (%.3f)' % (mean(adabr_scores), std(adabr_scores)))
# Out:
# MAE: -34.553 (3.443)

# %%
#Prediction of Test and Training set result  
Y_pred= clf.predict(X_test)  
X_pred= clf.predict(X_train)

# %%
adabr_score = r2_score(Y_test, Y_pred)
adabr_score
# Out:
# 0.7111381633714957

# %%
from sklearn.metrics import mean_squared_error
import math
# root mean square calculated by sklearn package
adabr_mse1 = math.sqrt(mean_squared_error(Y_test, Y_pred))
print('Root mean square error', adabr_mse1)
 
# where as the another way to find RMSE
# is by adding squared attribute as false in mean_squared_error
mse2 = mean_squared_error(Y_test, Y_pred)
print('Root mean square error', mse2)
# Out:
# Root mean square error 32.216071381068886
# Root mean square error 1037.8752552301255

# %%
from sklearn.preprocessing import MinMaxScaler


# preprocessing using 0-1 scaling
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_test)

# learning an LogisticRegression on the scaled training data
clf.fit(X_train_scaled, Y_train)

# scoring on the scaled test set
print("Scaled train set accuracy: {:.2f}".format(
    clf.score(X_train_scaled, Y_train)))
print("Scaled test set accuracy: {:.2f}".format(
    clf.score(X_val_scaled, Y_test)))
# Out:
# Scaled train set accuracy: 0.88
# Scaled test set accuracy: 0.78

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_test)

# learning an LogisticRegression on the scaled training data
clf.fit(X_train_scaled, Y_train)

# scoring on the scaled test set
print("Scaled train set accuracy: {:.2f}".format(
    clf.score(X_train_scaled, Y_train)))
print("Scaled test set accuracy: {:.2f}".format(
    clf.score(X_val_scaled, Y_test)))
# Out:
# Scaled train set accuracy: 0.88
# Scaled test set accuracy: 0.82

# %%
# Applying PCA function on training
# and testing set of X component
from sklearn.decomposition import PCA
 
pca = PCA(n_components = 2)
 
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
 
explained_variance = pca.explained_variance_ratio_

# %%
# Fitting Logistic Regression To the training set
from sklearn.tree import DecisionTreeRegressor
 
classifier =DecisionTreeRegressor(random_state = 0)
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
# Predicting the test set result using
# predict function under LogisticRegression
y_pred = classifier.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   60.000000
# 1367   115.0   35.000000
# 224    150.0   45.500000
# 641     85.0   60.000000
# 1290   115.0   90.000000
# 840     80.0   27.000000
# 326    150.0  155.000000
# 1895   135.0  125.000000
# 775    100.0  115.000000
# 3704    47.0   40.000000
# 1530    40.0  120.000000
# 1739   155.0  158.000000
# 3642    30.0   33.000000
# 1300   120.0   38.000000
# 2643   105.0   29.500000
# 979     31.0   36.000000
# 3039    67.0   63.000000
# 1385    27.0   30.000000
# 1377    71.0  215.000000
# 3392    65.0   75.000000
# 248    120.0  125.000000
# 572    115.0  115.000000
# 3800   100.0   88.000000
# 661    100.0   95.000000
# 1287    90.0   30.500000
# 1327    94.0   42.000000
# 962     17.0   19.000000
# 2604    95.0  100.000000
# 31     160.0   80.000000
# 3934    37.0   27.000000
# ...      ...         ...
# 1014    14.0   13.000000
# 3063    37.0   37.000000
# 1267    40.0   35.000000
# 3282    33.0   35.000000
# 3009    42.0   40.000000
# ...

# %%
score = r2_score(Y_test, y_pred)
score
# Out:
# 0.053599604032193215

# %%
#Model
from sklearn.linear_model import Ridge, RidgeCV, Lasso
lr = LinearRegression()

#Fit model
lr.fit(X_train, Y_train)

#predict
#prediction = lr.predict(X_test)

#actual
actual = Y_test

train_score_lr = lr.score(X_train, Y_train)
test_score_lr = lr.score(X_test, Y_test)

print("The train score for lr model is {}".format(train_score_lr))
print("The test score for lr model is {}".format(test_score_lr))


#Ridge Regression Model
ridgeReg = Ridge(alpha=0.1)

ridgeReg.fit(X_train,Y_train)

#train and test scorefor ridge regression
train_score_ridge = ridgeReg.score(X_train, Y_train)
test_score_ridge = ridgeReg.score(X_test, Y_test)

print("\nRidge Model............................................\n")
print("The train score for ridge model is {}".format(train_score_ridge))
print("The test score for ridge model is {}".format(test_score_ridge))
# Out:
# The train score for lr model is 0.26391174455875543
# The test score for lr model is 0.23216175040796472
#
# Ridge Model............................................
#
# The train score for ridge model is 0.2639117445587553
# The test score for ridge model is 0.2321617523084598

# %%
#import required packages
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train, Y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 58.70063766199381
# RMSE value for k=  2 is: 52.769707476891064
# RMSE value for k=  3 is: 50.521464191232965
# RMSE value for k=  4 is: 52.46600872615259
# RMSE value for k=  5 is: 50.58011822675621
# RMSE value for k=  6 is: 49.71724477890335
# RMSE value for k=  7 is: 49.31893461702286
# RMSE value for k=  8 is: 49.488818734998766
# RMSE value for k=  9 is: 49.415174084747704
# RMSE value for k=  10 is: 49.2653958477294
# RMSE value for k=  11 is: 49.345822535111566
# RMSE value for k=  12 is: 49.34967969071812
# RMSE value for k=  13 is: 49.28824603791954
# RMSE value for k=  14 is: 49.72930642501913
# RMSE value for k=  15 is: 49.60889352789308
# RMSE value for k=  16 is: 49.651302720008594
# RMSE value for k=  17 is: 49.72469168165191
# RMSE value for k=  18 is: 49.65581069961878
# RMSE value for k=  19 is: 49.95284096358158
# RMSE value for k=  20 is: 49.93368133215048

# %%
#Prediction of Test and Training set result  
Y_pred= model.predict(X_test)  
X_pred= model.predict(X_train)

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()

# %%
predict = model.predict(X_test)
predict
error = sqrt(mean_squared_error(Y_test,predict)) #calculate rmse
rmse_val.append(error) #store rmse values
print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  20 is: 49.93368133215048

# %%
from sklearn.preprocessing import StandardScaler as SS  
SC = SS()  
   
X_train = SC.fit_transform(X_train)  
X_test = SC.transform(X_test)

# %%
from sklearn.decomposition import PCA  
   
PCa = PCA (n_components = 1)  
   
X_train = PCa.fit_transform(X_train)  
X_test = PCa.transform(X_test)  
   
explained_variance = PCa.explained_variance_ratio_

# %%
from sklearn.ensemble import RandomForestRegressor

classifier = RandomForestRegressor(max_depth=2, random_state=0)
classifier.fit(X_train, Y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
Y_pred = classifier.predict(X_test)

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
df
# Out:
#       Actual   Predicted
# 3322    21.0   49.879076
# 1367   115.0   87.365549
# 224    150.0   87.365549
# 641     85.0   87.365549
# 1290   115.0   87.365549
# 840     80.0   87.365549
# 326    150.0   87.365549
# 1895   135.0   87.365549
# 775    100.0   87.365549
# 3704    47.0  131.213999
# 1530    40.0   87.365549
# 1739   155.0   87.365549
# 3642    30.0   66.566563
# 1300   120.0   87.365549
# 2643   105.0   66.566563
# 979     31.0   87.365549
# 3039    67.0   81.686445
# 1385    27.0   87.365549
# 1377    71.0   87.365549
# 3392    65.0   72.516895
# 248    120.0   87.365549
# 572    115.0   87.365549
# 3800   100.0   49.879076
# 661    100.0   87.365549
# 1287    90.0   87.365549
# 1327    94.0   87.365549
# 962     17.0   87.365549
# 2604    95.0   72.516895
# 31     160.0   87.365549
# 3934    37.0   64.396512
# ...      ...         ...
# 1014    14.0   87.365549
# 3063    37.0   72.516895
# 1267    40.0   87.365549
# 3282    33.0   72.516895
# 3009    42.0  131.213999
# ...

# %%
#compare between models

# %%
scores = [dtr_score,lr_score,l_score,rfr_score,knr_score]
algorithms = ["DessionTreeRegressor","LinearRegression","Lasso","RandomForestRegressor","KNeighborsRegressor"]    

for i in range(len(algorithms)):
    print("The  score achieved using "+algorithms[i]+" is: "+str(scores[i]))
# Out:
# The  score achieved using DessionTreeRegressor is: 0.8381215448501121
# The  score achieved using LinearRegression is: 0.7361698770518049
# The  score achieved using Lasso is: 0.7200112110107217
# The  score achieved using RandomForestRegressor is: 0.8821764891311741
# The  score achieved using KNeighborsRegressor is: 0.7111381633714957

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Models")
plt.ylabel("Score")

sns.barplot(algorithms,scores)

# %%
rmse = [dtr_mse1,lr_mse1,l_mse1,rfr_mse1,knr_mse1]
algorithms = ["DessionTreeRegressor","LinearRegression","Lasso","RandomForestRegressor","KNeighborsRegressor"]    

for i in range(len(algorithms)):
    print("rmse "+algorithms[i]+" is: "+str(rmse[i]))
# Out:
# rmse DessionTreeRegressor is: 24.116929860664907
# rmse LinearRegression is: 30.788581800982683
# rmse Lasso is: 31.717417274965275
# rmse RandomForestRegressor is: 20.575172005186158
# rmse KNeighborsRegressor is: 32.216071381068886

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("rmse")

sns.barplot(algorithms,rmse)
